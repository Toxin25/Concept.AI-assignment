# %% [markdown]
# # Assignment **1**

# %%
# importing the dataset from google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Loading dataset from google drive
data = pd.read_csv('/content/drive/MyDrive/Assignment1/WHR-2024-5CS037.csv')

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ## Data exploration and understanding

# %%
#Data Overview
#q1
data.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
data.describe()
# Out:
#             score  Log GDP per capita  Social support  \
# count  143.000000          140.000000      140.000000
# mean     5.527580            1.378807        1.134329
# std      1.170717            0.425098        0.333317
# min      1.721000            0.000000        0.000000
# 25%      4.726000            1.077750        0.921750
# 50%      5.785000            1.431500        1.237500
# 75%      6.416000            1.741500        1.383250
# max      7.741000            2.141000        1.617000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               140.000000                    140.000000  140.000000
# mean                  0.520886                      0.620621    0.146271
# std                   0.164923                      0.162492    0.073441
# min                   0.000000                      0.000000    0.000000
# 25%                   0.398000                      0.527500    0.091000
# ...

# %%
#q2
data.shape
# Out:
# (143, 9)

# %%
#q3
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  143 non-null    object
#  1   score                         143 non-null    float64
#  2   Log GDP per capita            140 non-null    float64
#  3   Social support                140 non-null    float64
#  4   Healthy life expectancy       140 non-null    float64
#  5   Freedom to make life choices  140 non-null    float64
#  6   Generosity                    140 non-null    float64
#  7   Perceptions of corruption     140 non-null    float64
#  8   Dystopia + residual           140 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 10.2+ KB

# %%
#Basic statisctics
#q1
mean_value = data['score'].mean()
print(f"mean: {mean_value}")

median_value = data['score'].median()
print(f"median: {median_value}")

std_value = data['score'].std()
print(f"standard deviation: {std_value}")
# Out:
# mean: 5.52758041958042
# median: 5.785
# standard deviation: 1.1707165099442995

# %%
#q2
happiness_score_high = data.loc[data['score'].idxmax()]
happiest_country = happiness_score_high['Country name']
print(f"Most happiest country is: {happiest_country}")

happiness_score_low = data.loc[data['score'].idxmin()]
saddest_country = happiness_score_low['Country name']
print(f"Most saddest country is: {saddest_country}")
# Out:
# Most happiest country is: Finland
# Most saddest country is: Afghanistan

# %%
#Missing values
#q1
null_values = data.isnull().sum()
print(null_values)
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %%
#Filtering and sorting
#q1
high_score = data.loc[data['score'] > 7.5]
high_score_country = high_score['Country name']
print(high_score_country)
# Out:
# 0    Finland
# 1    Denmark
# 2    Iceland
# Name: Country name, dtype: object

# %%
#q2
sortby_gdp = data.sort_values('Log GDP per capita', ascending=False)
sortby_gdp.head(10)
# Out:
#                  Country name  score  Log GDP per capita  Social support  \
# 7                  Luxembourg  7.122               2.141           1.355
# 16                    Ireland  6.838               2.129           1.390
# 29                  Singapore  6.523               2.118           1.361
# 21       United Arab Emirates  6.733               1.983           1.164
# 8                 Switzerland  7.060               1.970           1.425
# 6                      Norway  7.302               1.952           1.517
# 22              United States  6.725               1.939           1.392
# 85  Hong Kong S.A.R. of China  5.316               1.909           1.184
# 1                     Denmark  7.583               1.908           1.520
# 5                 Netherlands  7.319               1.901           1.462
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 7                     0.708                         0.801       0.146
# ...

# %%
#q3
def category_slection(value):
  if value<4:
    return 'Low'
  elif value >= 4 and value <=6:
    return 'Medium'
  else:
    return 'High'

data['Happiness Category'] = data['score'].apply(category_slection)
data.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# ## Data visualization

# %%
#Bar plot

top_10_happiest_country = data.sort_values('score', ascending=False).head(10)
top_10_happiest_country
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
plt.bar(top_10_happiest_country['Country name'], top_10_happiest_country['score'])
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.title('Top 10 Happiest Countries')
plt.xticks(rotation=90)
plt.show()

# %%
#Line plot
top_10_saddest_country = data.sort_values('score').head(10)
top_10_saddest_country
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 142       Afghanistan  1.721               0.628           0.000
# 141           Lebanon  2.707               1.377           0.577
# 140           Lesotho  3.186               0.771           0.851
# 139      Sierra Leone  3.245               0.654           0.566
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 137          Zimbabwe  3.341               0.748           0.850
# 136          Botswana  3.383               1.445           0.969
# 135            Malawi  3.421               0.617           0.410
# 134          Eswatini  3.502               1.255           0.925
# 133            Zambia  3.502               0.899           0.809
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                         0.000       0.091
# 141                    0.556                         0.173       0.068
# ...

# %%
plt.plot(top_10_saddest_country['Country name'], top_10_saddest_country['score'], marker='o')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.title('Top 10 Saddest Countries')
plt.xticks(rotation=90)
plt.show()

# %%
#Histogram

plt.hist(data['score'], bins=12, edgecolor='black')
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.title('Distribution of Happiness Scores')
plt.show()

# %%
  #Scatter plot

plt.scatter(data['score'], data['Log GDP per capita'])
plt.xlabel('Happiness Score')
plt.ylabel('Log GDP per capita')
plt.title('Happiness Score vs. Log GDP per capita')
plt.show()

# %% [markdown]
# ## Advance data exploration task

# %%
# Set up south asian dataset
#q1
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# %%
#q2
south_asian_data = data[data['Country name'].isin(south_asian_countries)]
south_asian_data
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
#q3
south_asian_data.to_csv('/content/drive/MyDrive/Assignment1/South-asian-countries.csv', index=False)

# %%
data_south_asia = pd.read_csv('/content/drive/MyDrive/Assignment1/South-asian-countries.csv')

# %%
data_south_asia.describe()
# Out:
#           score  Log GDP per capita  Social support  Healthy life expectancy  \
# count  6.000000            6.000000        6.000000                 6.000000
# mean   3.895667            1.051833        0.611833                 0.420333
# std    1.177069            0.245361        0.441024                 0.125082
# min    1.721000            0.628000        0.000000                 0.242000
# 25%    3.889000            0.991000        0.336750                 0.345000
# 50%    3.976000            1.095500        0.626500                 0.430000
# 75%    4.506250            1.155000        0.905750                 0.495500
# max    5.158000            1.361000        1.179000                 0.586000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                      6.000000    6.000000                   6.000000
# mean                       0.553333    0.150333                   0.099500
# ...

# %%
  #Composite Score Ranking
#q1

data_south_asia['Composite Score'] = 0.40*data_south_asia['Log GDP per capita']+0.30*data_south_asia['Social support']+0.30*data_south_asia['Healthy life expectancy']
data_south_asia
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %%
#q2
rankby_composite_score = data_south_asia.sort_values('Composite Score', ascending=False).head(5)
rankby_composite_score
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 3    Sri Lanka  3.898               1.361           1.179
# 0        Nepal  5.158               0.965           0.990
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 4   Bangladesh  3.886               1.122           0.249
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 4                    0.513                         0.775       0.140
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 3                      0.031                0.014                Low
# ...

# %%
#q3
plt.barh(rankby_composite_score['Country name'], rankby_composite_score['Composite Score'])
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.title('Composite Score Ranking')
plt.show()

# %%
bar_width = 0.4
x_axis = np.arange(len(rankby_composite_score['Country name']))

plt.figure(figsize=(12, 6))
plt.bar( x_axis - bar_width / 2, rankby_composite_score['score'],bar_width,label='Happiness Score')
plt.bar(x_axis + bar_width / 2,rankby_composite_score['Composite Score'],bar_width,color='green',label='Composite Score')
plt.xticks(x_axis , rankby_composite_score['Country name'], rotation=90)
plt.xlabel('Country Name')
plt.title('Composite score alignment with Happiness Score ')
plt.legend()
plt.show()

# %%
#Outlier detection
#q1 and q2
q1_happiness_score = data_south_asia['score'].quantile(0.25)
q3_happiness_score = data_south_asia['score'].quantile(0.75)
iqr_happiness_score = q3_happiness_score - q1_happiness_score

lower_bound_happiness_score = q1_happiness_score - 1.5 * iqr_happiness_score
upper_bound_happiness_score = q3_happiness_score + 1.5 * iqr_happiness_score

q1_gdp_score = data_south_asia['Log GDP per capita'].quantile(0.25)
q3_gdp_score = data_south_asia['Log GDP per capita'].quantile(0.75)
iqr_gdp_score = q3_gdp_score - q1_gdp_score

lower_bound_gdp_score = q1_gdp_score - 1.5 * iqr_gdp_score
upper_bound_gdp_score = q3_gdp_score + 1.5 * iqr_gdp_score

# Use data_south_asia instead of data for filtering
outliers = data_south_asia[(data_south_asia['score'] < lower_bound_happiness_score) |
                (data_south_asia['score'] > upper_bound_happiness_score) |
                (data_south_asia['Log GDP per capita'] < lower_bound_gdp_score) |
                 (data_south_asia['Log GDP per capita'] > upper_bound_gdp_score)]
outliers
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628             0.0
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                           0.0       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 5                      0.088                0.672                Low
#
#    Composite Score
# 5           0.3238

# %%
#q3
plt.scatter(data_south_asia['Log GDP per capita'], data_south_asia['score'],label='Normal Data')
plt.scatter(outliers['Log GDP per capita'], outliers['score'], color='red', label='Outliers')
plt.xlabel('Log GDP per capita')
plt.ylabel('Happiness Score')
plt.title('Outlier Detection in south asian countries')
plt.legend(loc='upper left')
plt.show()

# %%
#Exploring trends across metrices
#q1
corr_freedom_value = data_south_asia['Freedom to make life choices'].corr(data_south_asia['score'])
print(f"Correlation value of Freedom to make life choices: {corr_freedom_value}")

corr_generocity_value = data_south_asia['Generosity'].corr(data_south_asia['score'])
print(f"Correlation value of Generocity: {corr_generocity_value}")
# Out:
# Correlation value of Freedom to make life choices: 0.8005185224163315
# Correlation value of Generocity: 0.874512371253192

# %%
sns.regplot(x='Freedom to make life choices', y='score', data=data_south_asia)
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness Score')
plt.title('Freedom to make life choices vs. Happiness Score')
plt.show()

# %%
sns.regplot(x='Generosity', y='score', data=data_south_asia)
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.title('Generosity vs. Happiness Score')
plt.show()

# %%
#Gap analysis
#q1

data_south_asia['GDP_Score Gap'] = data_south_asia['Log GDP per capita'] - data_south_asia['score']
data_south_asia
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %%
#Q2
#Ascending oder
asce_gpd_score_gap = data_south_asia.sort_values('GDP_Score Gap')
asce_gpd_score_gap
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 4   Bangladesh  3.886               1.122           0.249
# 3    Sri Lanka  3.898               1.361           1.179
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 4                    0.513                         0.775       0.140
# 3                    0.586                         0.583       0.144
# 5                    0.242                         0.000       0.091
#
# ...

# %%
#Descending Order
desc_gpd_score_gap = data_south_asia.sort_values('GDP_Score Gap', ascending=False)
desc_gpd_score_gap
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628           0.000
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 0        Nepal  5.158               0.965           0.990
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 0                    0.443                         0.653       0.209
#
# ...

# %%
#q3
positive_top_3 = asce_gpd_score_gap.head(3)
negative_top_3 = desc_gpd_score_gap.head(3)

plt.bar(positive_top_3['Country name'], positive_top_3['GDP_Score Gap'], label='Positive Gap')
plt.xlabel('Country')
plt.ylabel('GDP Score Gap')
plt.title('Top 3 Countries with Positive GDP Score Gaps')
plt.gca().invert_yaxis()
plt.legend()
plt.show()

# %%
plt.bar(negative_top_3['Country name'], negative_top_3['GDP_Score Gap'], label='Negative Gap')
plt.xlabel('Country')
plt.ylabel('GDP Score Gap')
plt.title('Top 3 Countries with Negative GDP Score Gaps')
plt.gca().invert_yaxis()
plt.legend()
plt.show()

# %% [markdown]
# ## Comparative Analysis:

# %%
#Preparing middle eastern dataset
#q1

middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan","Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]

# %%
middle_eastern_data = data[data['Country name'].isin(middle_east_countries)]
middle_eastern_data
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %%
middle_eastern_data.to_csv('/content/drive/MyDrive/Assignment1/Middle-eastern-countries.csv', index=False)

# %%
data_middle_east = pd.read_csv('/content/drive/MyDrive/Assignment1/Middle-eastern-countries.csv')
data_middle_east.describe()
# Out:
#            score  Log GDP per capita  Social support  Healthy life expectancy  \
# count  10.000000            9.000000        9.000000                 9.000000
# mean    5.412100            1.496333        1.152778                 0.554111
# std     1.566201            0.416414        0.278277                 0.123047
# min     2.707000            0.671000        0.577000                 0.293000
# 25%     4.370250            1.262000        0.996000                 0.511000
# 50%     5.562500            1.435000        1.164000                 0.563000
# 75%     6.698250            1.842000        1.361000                 0.594000
# max     7.341000            1.983000        1.513000                 0.740000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                      9.000000    9.000000                   9.000000
# mean                       0.554333    0.139889                   0.145889
# ...

# %%
#Descriptive stat
#q1
mean_sa = data_south_asia['score'].mean()
print(f"mean of south asia: {mean_sa}")

mean_me = data_middle_east['score'].mean()
print(f"mean of middle east: {mean_me}")

std_sa = data_south_asia['score'].std()
print(f"standard deviation of south asia: {std_sa}")

std_me = data_middle_east['score'].std()
print(f"standard deviation of middle east: {std_me}")
# Out:
# mean of south asia: 3.895666666666667
# mean of middle east: 5.412100000000001
# standard deviation of south asia: 1.1770690152521504
# standard deviation of middle east: 1.5662011684327144

# %% [markdown]
# **The average happiness score of middle eastern countries is higher compared to south asian countries.**

# %%
#top and bottom performers
#q1
sa_top_3_countries = data_south_asia.sort_values('score', ascending=False).head(3)
me_top_3_countries = data_middle_east.sort_values('score', ascending=False).head(3)

# %%
sa_top_3_countries
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 0                      0.115                1.783             Medium
# 1                      0.074                1.907             Medium
# 2                      0.122                0.756             Medium
#
#    Composite Score  GDP_Score Gap
# 0           0.8159         -4.193
# 1           0.7039         -3.588
# 2           0.7874         -2.888

# %%
me_top_3_countries
# Out:
#            Country name  score  Log GDP per capita  Social support  \
# 0                Israel  7.341               1.803           1.513
# 1                Kuwait  6.951               1.845           1.364
# 2  United Arab Emirates  6.733               1.983           1.164
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.740                         0.641       0.153
# 1                    0.661                         0.827       0.200
# 2                    0.563                         0.815       0.209
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# 0                      0.193                2.298               High
# 1                      0.172                1.884               High
# 2                      0.258                1.741               High

# %%
sa_bottom_3_countries = data_south_asia.sort_values('score').head(3)
me_bottom_3_countries = data_middle_east.sort_values('score').head(3)

# %%
sa_bottom_3_countries
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628           0.000
# 4   Bangladesh  3.886               1.122           0.249
# 3    Sri Lanka  3.898               1.361           1.179
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 4                    0.513                         0.775       0.140
# 3                    0.586                         0.583       0.144
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 5                      0.088                0.672                Low
# 4                      0.167                0.919                Low
# 3                      0.031                0.014                Low
#
#    Composite Score  GDP_Score Gap
# 5           0.3238         -1.093
# 4           0.6774         -2.764
# 3           1.0739         -2.537

# %%
me_bottom_3_countries
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 9      Lebanon  2.707               1.377           0.577
# 8        Yemen  3.561               0.671           1.281
# 7       Jordan  4.186               1.262           0.983
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 9                    0.556                         0.173       0.068
# 8                    0.293                         0.362       0.080
# 7                    0.594                         0.593       0.059
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# 9                      0.029               -0.073                Low
# 8                      0.113                0.760                Low
# 7                      0.189                0.504             Medium

# %%
#q2

plt.bar(me_bottom_3_countries['Country name'], me_bottom_3_countries['score'], label='middle east')
plt.bar(sa_bottom_3_countries['Country name'], sa_bottom_3_countries['score'], label='south asia')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.title('Top 3 Countries with lowest Scores in each region')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
plt.bar(me_top_3_countries['Country name'], me_top_3_countries['score'], label='middle east')
plt.bar(sa_top_3_countries['Country name'], sa_top_3_countries['score'], label='south asia')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.title('Top 3 Countries with highest Happiness Scores in each region')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
data_middle_east['region'] = 'middle-east'
data_south_asia['region'] = 'south-asia'

# %%
sa_mean = data_south_asia.groupby('region')[['Log GDP per capita', 'Social support', 'Healthy life expectancy']].mean()

# %%
me_mean = data_middle_east.groupby('region')[['Log GDP per capita', 'Social support', 'Healthy life expectancy']].mean()

# %%
x = np.arange(len(sa_mean.columns))
width = 0.3

fig, ax = plt.subplots(figsize=(10, 6))
for i, region in enumerate(sa_mean.index):
    ax.bar(x + i * width, sa_mean.loc[region], width, label=region)

for i, region in enumerate(me_mean.index):
    ax.bar(x + (i + 1) * width, me_mean.loc[region], width, label=region)

ax.set_xticks(x + width / 2)
ax.set_xticklabels(sa_mean.columns)
ax.set_ylabel('Average Value')
ax.set_title('Comparison of Metrics Between Regions')
ax.legend(title="Region")
plt.tight_layout()
plt.show()

# %%
sa_mean
# Out:
#             Log GDP per capita  Social support  Healthy life expectancy
# region
# south-asia            1.051833        0.611833                 0.420333

# %%
me_mean
# Out:
#              Log GDP per capita  Social support  Healthy life expectancy
# region
# middle-east            1.496333        1.152778                 0.554111

# %% [markdown]
# **The largest disparity between two regions can be observed in social support as difference is comparitively higher compared to other metrices**
#
# > Add blockquote

# %%
#happiness disparity
#q1
max_value_sa = data_south_asia['score'].max()
min_value_sa = data_south_asia['score'].min()
max_value_me = data_middle_east['score'].max()
min_value_me = data_middle_east['score'].min()

range_sa = max_value_sa - min_value_sa
range_me = max_value_me - min_value_me

# %%
range_sa
# Out:
# 3.4370000000000003

# %%
range_me
# Out:
# 4.634

# %%
coff_sa = (data_south_asia['score'].std())/(data_south_asia['score'].mean())
coff_me = (data_middle_east['score'].std())/(data_middle_east['score'].mean())

# %%
coff_sa*100
# Out:
# 30.21482883337427

# %%
coff_me*100
# Out:
# 28.938880812119404

# %% [markdown]
# **The region which has the greater variability is middle eastern region because cofficient of varience is slightly higher than south asian region**

# %%
#Correlation Analysis
#q1
sa_corr_freedom = data_south_asia['Freedom to make life choices'].corr(data_south_asia['score'])
sa_corr_generocity = data_south_asia['Generosity'].corr(data_south_asia['score'])

me_corr_freedom = data_middle_east['Freedom to make life choices'].corr(data_middle_east['score'])
me_corr_generocity = data_middle_east['Generosity'].corr(data_middle_east['score'])

# %%
sa_corr_freedom
# Out:
# 0.8005185224163315

# %%
sa_corr_generocity
# Out:
# 0.874512371253192

# %%
me_corr_freedom
# Out:
# 0.8632202433827543

# %%
me_corr_generocity
# Out:
# 0.6275236536964182

# %%
plt.scatter(data_middle_east['Freedom to make life choices'], data_middle_east['score'])
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness Score')
plt.title('Freedom to make life choices vs. Happiness Score Middle East')
plt.show()

# %%
plt.scatter(data_middle_east['Generosity'], data_middle_east['score'])
plt.xlabel('Generocity')
plt.ylabel('Happiness Score')
plt.title('Generosity vs. Happiness Score Middle East')
plt.show()

# %%
plt.scatter(data_south_asia['Freedom to make life choices'], data_south_asia['score'])
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness Score')
plt.title('Freedom to make life choices vs. Happiness Score South Asia')
plt.show()

# %%
plt.scatter(data_south_asia['Generosity'], data_south_asia['score'])
plt.xlabel('Generocity')
plt.ylabel('Happiness Score')
plt.title('Generosity vs. Happiness Score South Asia')
plt.show()

# %%
#Outlier Analysis
#q1
def outliers_iqr(data, column_name):
    q1 = data[column_name].quantile(0.25)
    q3 = data[column_name].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    outliers = data[(data[column_name] < lower_bound) | (data[column_name] > upper_bound)]
    return outliers

me_outlier_score = outliers_iqr(data_middle_east, 'score')
sa_outlier_score = outliers_iqr(data_south_asia, 'score')
me_outlier_gdp = outliers_iqr(data_middle_east, 'Log GDP per capita')
sa_outlier_gdp = outliers_iqr(data_south_asia, 'Log GDP per capita')

# %%
sa_concat_oulier = pd.concat([sa_outlier_score, sa_outlier_gdp]).drop_duplicates()
me_concat_oulier = pd.concat([me_outlier_score, me_outlier_gdp]).drop_duplicates()

# %%
sa_concat_oulier
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628             0.0
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                           0.0       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 5                      0.088                0.672                Low
#
#    Composite Score  GDP_Score Gap      region
# 5           0.3238         -1.093  south-asia

# %%
me_concat_oulier
# Out:
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Dystopia + residual, Happiness Category, region]
# Index: []

# %%
plt.scatter(
    data_middle_east['Log GDP per capita'],
    data_middle_east['score'],
    label='Middle East Data',
)
plt.scatter(
    me_concat_oulier['Log GDP per capita'],
    me_concat_oulier['score'],
    label='Middle East Outlier',
)
plt.xlabel('GDP per capita')
plt.ylabel('Happiness Score')
plt.title('Outliers middle east')
plt.legend()
plt.show()

# %%
plt.scatter(
    data_south_asia['Log GDP per capita'],
    data_south_asia['score'],
    label='South Asia',
    color='blue'
)
plt.scatter(
    sa_concat_oulier['Log GDP per capita'],
    sa_concat_oulier['score'],
    label='South Asia Outlier',
    color='red'
)
plt.xlabel('GDP per capita')
plt.ylabel('Happiness Score')
plt.title('Outliers south asia')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# **Observing this scatter plots we can conclude that in middle eastern region no outliers were found and in south asia one outlier afganistan is found**

# %%
data_concat_me_sa = pd.concat([data_middle_east[['score']].assign(Region='Middle East'),data_south_asia[['score']].assign(Region='South Asia'),])

# %%
data_concat_me_sa
# Out:
#    score       Region
# 0  7.341  Middle East
# 1  6.951  Middle East
# 2  6.733  Middle East
# 3  6.594  Middle East
# 4  5.959  Middle East
# 5  5.166  Middle East
# 6  4.923  Middle East
# 7  4.186  Middle East
# 8  3.561  Middle East
# 9  2.707  Middle East
# 0  5.158   South Asia
# 1  4.657   South Asia
# 2  4.054   South Asia
# 3  3.898   South Asia
# 4  3.886   South Asia
# 5  1.721   South Asia

# %%
sns.boxplot(
    x='Region',
    y='score',
    data=data_concat_me_sa,
    palette='Set3',
    linewidth=1.5,
)
plt.title('Score distribution between south asia and middle east')
plt.xlabel('Region')
plt.ylabel('Score')
plt.show()
# Out:
# <ipython-input-81-3a112ad5c09d>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
combined_df = pd.concat([data, data_south_asia, data_middle_east], keys=['Global', 'South Asia', 'Middle East'], names=['Region', 'Index'])

print("\nCombined Dataset Summary:")
combined_df.describe()
# Out:
# Combined Dataset Summary:
#             score  Log GDP per capita  Social support  \
# count  159.000000          155.000000      155.000000
# mean     5.458736            1.372974        1.115174
# std      1.229863            0.423093        0.347712
# min      1.721000            0.000000        0.000000
# 25%      4.526500            1.077500        0.905000
# 50%      5.714000            1.398000        1.191000
# 75%      6.416000            1.745000        1.369000
# max      7.741000            2.141000        1.617000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               155.000000                    155.000000  155.000000
# mean                  0.518923                      0.614168    0.146058
# std                   0.162170                      0.172497    0.071689
# min                   0.000000                      0.000000    0.000000
# 25%                   0.400000                      0.523000    0.091000
# ...

# %%
# Correlation Heatmap for Combined Dataset
numeric_cols_combined = combined_df.select_dtypes(include='number')
combined_corr = numeric_cols_combined.corr()

plt.figure(figsize=(12, 6))
sns.heatmap(combined_corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Combined Dataset Correlation Heatmap")
plt.show()
